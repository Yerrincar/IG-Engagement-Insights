# %%
import pandas as pd

#Implementación para eliminar los duplicados de la columna 'ownerUsername' y así obtener solo los usuarios de los que hemos obtenido datos, pues
# debido a la capacidad del scrapper, se han obtenido datos de 300 cuentas, pero no de todas las deseadas.

datos_posts = pd.read_csv(r'C:\Users\Yeray\Desktop\DATA_SCIENCE_ML\IG-Engagemente-Insights\DATA\dataset_instagram-post-scraper_2025-02-22_15-16-27-556.csv')
usuarios = datos_posts['ownerUsername'].unique()
print(usuarios)

usuarios_csv = pd.DataFrame(usuarios, columns=['usuarios'])
#URL de cada usuario para hacer el scrapping de su número de seguidores y seguidos
usuarios_csv['url'] = 'https://www.instagram.com/' + usuarios_csv['usuarios'] + '/'
#Exportamos a csv
usuarios_csv.to_csv(r'C:\Users\Yeray\Desktop\DATA_SCIENCE_ML\IG-Engagemente-Insights\DATA\usuarios.csv')
# Out:
# [nan 'leercomopetitpleasure' 'julia_books04' 'cozytales_books'
#  'loslibrosdeandrea' 'booksbyhoneydukes' 'elvisisreading' 'luciawrotehere'
#  'uda_liburuartean' 'the.bookis.girl' 'samantavuks' 'x' 'lavidaendrama'
#  'i.bookstagrammer' 'eternal_autumnabooks' 'oxodiaxoias'
#  'vientonorteeditorial' 'nicolas.diez.barros' 'gemss_ps' 'aity.books'
#  'momitalectora' 'siescribo' 'soyrociosierrabooks' 'lexa.libros_11'
#  'labibliotecadelorena_' 'loslibrosdemirii' 'andreabooks15'
#  'mskarmaisabook' 'aroalovesreading' 'asteriereads' 'callmereader_'
#  'paulitabooks' 'read.is.wonder' 'carlabookish' 'rustibook'
#  'sorayacortes.coach' 'concubinachilena' 'liaa_books' 'mariaponcefantasy'
#  'un.amor.inesperado' 'booksmagic22' 'libroterapeuta' 'itsandreabooks'
#  'refugio_entre_libros_y_cafe' 'elenaa.reads' 'eli.bookss'
#  'bookcornerbyjudith' 'sephorabooks_' 'josedommart' 'patritasbooks'
#  '_cecibooks_' 'butterboooks' 'cajadepandora.crochet' 'marien_libros79'
# ...
